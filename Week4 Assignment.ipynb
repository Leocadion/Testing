# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Reinis Reinholds Ruza** <br>
# Current occupation: Structural Biologist

# %% [markdown]
# *I am interested in data science because familiarity with this field has the potential to help me in my current job, as well as open new possibilities for my future career*

# %% [markdown]
# ### The code in the cell below shows the current time

# %%
from datetime import datetime

time = datetime.now()
time_format = time.strftime("%H:%M:%S")
print("The current time is", time_format)
# Out:
# The current time is 21:47:53

# %% [markdown]
# In this final section I will just show you three random things:
#  - First one is the [Norwegian Meteorological Service website](https://www.yr.no/en/forecast/daily-table/2-2643743/Great%20Britain/England/Greater%20London/London), which  is objectively the best website for getting weather information
#  - The second one is this bulleted list itself
#  - And the third is this meme about data science
# ![image.png](attachment:image.png)
